# %%
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec
# Out:
# Using TensorFlow backend.

# %%
def get_images(directory):
    Images = []
    Labels = []  # 0 for Building , 1 for forest, 2 for glacier, 3 for mountain, 4 for Sea , 5 for Street
    label = 0
    
    for labels in os.listdir(directory): #Main Directory where each class label is present as folder name.
        if labels == 'glacier': #Folder contain Glacier Images get the '2' class label.
            label = 2
        elif labels == 'sea':
            label = 4
        elif labels == 'buildings':
            label = 0
        elif labels == 'forest':
            label = 1
        elif labels == 'street':
            label = 5
        elif labels == 'mountain':
            label = 3
            
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(150,150)) #Resize the image, Some images are different sizes. (Resizing is very Important)
            Images.append(image)
            Labels.append(label)
    
    return shuffle(Images,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

def get_classlabel(class_code):
    labels = {2:'glacier', 4:'sea', 0:'buildings', 1:'forest', 5:'street', 3:'mountain'}
    
    return labels[class_code]

# %%
Images, Labels = get_images('../input/intel-image-classification/seg_train/seg_train/') #Extract the training images from the folders.

Images = np.array(Images) #converting the list of images to numpy array.
Labels = np.array(Labels)

# %%
print("Shape of Images:",Images.shape)
print("Shape of Labels:",Labels.shape)
# Out:
# Shape of Images: (14034, 150, 150, 3)
# Shape of Labels: (14034,)

# %%
f,ax = plot.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(Images))
        ax[i,j].imshow(Images[rnd_number])
        ax[i,j].set_title(get_classlabel(Labels[rnd_number]))
        ax[i,j].axis('off')

# %%
model = Models.Sequential()

model.add(Layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(140,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(100,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(50,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Flatten())
model.add(Layers.Dense(180,activation='relu'))
model.add(Layers.Dense(100,activation='relu'))
model.add(Layers.Dense(50,activation='relu'))
model.add(Layers.Dropout(rate=0.5))
model.add(Layers.Dense(6,activation='softmax'))

model.compile(optimizer=Optimizer.Adam(lr=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.summary()
Utils.plot_model(model,to_file='model.png',show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 200)     5600
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 146, 146, 180)     324180
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 29, 29, 180)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 180)       291780
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 140)       226940
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 100)       126100
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 21, 21, 50)        45050
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 50)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 180)               144180
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               18100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 306
# =================================================================
# Total params: 1,187,286
# Trainable params: 1,187,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
trained = model.fit(Images,Labels,epochs=35,validation_split=0.30)
# Out:
# Train on 9823 samples, validate on 4211 samples
# Epoch 1/35
# 9823/9823 [==============================] - 52s 5ms/sample - loss: 1.5726 - accuracy: 0.3634 - val_loss: 1.0896 - val_accuracy: 0.5930
# Epoch 2/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 1.1566 - accuracy: 0.5391 - val_loss: 0.9065 - val_accuracy: 0.6481
# Epoch 3/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.9919 - accuracy: 0.6236 - val_loss: 0.7709 - val_accuracy: 0.7105
# Epoch 4/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.8940 - accuracy: 0.6820 - val_loss: 0.6811 - val_accuracy: 0.7540
# Epoch 5/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.7877 - accuracy: 0.7254 - val_loss: 0.6505 - val_accuracy: 0.7621
# Epoch 6/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.7221 - accuracy: 0.7467 - val_loss: 0.6149 - val_accuracy: 0.7808
# Epoch 7/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.6665 - accuracy: 0.7698 - val_loss: 0.5980 - val_accuracy: 0.7875
# Epoch 8/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.6236 - accuracy: 0.7845 - val_loss: 0.6589 - val_accuracy: 0.7727
# Epoch 9/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.5939 - accuracy: 0.7961 - val_loss: 0.5135 - val_accuracy: 0.8181
# Epoch 10/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.5472 - accuracy: 0.8114 - val_loss: 0.5495 - val_accuracy: 0.8084
# Epoch 11/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.5196 - accuracy: 0.8246 - val_loss: 0.5437 - val_accuracy: 0.8119
# Epoch 12/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.4808 - accuracy: 0.8351 - val_loss: 0.5090 - val_accuracy: 0.8209
# Epoch 13/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.4565 - accuracy: 0.8459 - val_loss: 0.4621 - val_accuracy: 0.8366
# Epoch 14/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.4179 - accuracy: 0.8582 - val_loss: 0.4808 - val_accuracy: 0.8364
# Epoch 15/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.3847 - accuracy: 0.8731 - val_loss: 0.4719 - val_accuracy: 0.8404
# Epoch 16/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.3516 - accuracy: 0.8764 - val_loss: 0.5395 - val_accuracy: 0.8266
# Epoch 17/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.3376 - accuracy: 0.8870 - val_loss: 0.5434 - val_accuracy: 0.8231
# Epoch 18/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.3074 - accuracy: 0.8964 - val_loss: 0.4443 - val_accuracy: 0.8530
# Epoch 19/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.2769 - accuracy: 0.9066 - val_loss: 0.5538 - val_accuracy: 0.8323
# Epoch 20/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.2541 - accuracy: 0.9146 - val_loss: 0.5058 - val_accuracy: 0.8542
# Epoch 21/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.2386 - accuracy: 0.9214 - val_loss: 0.6062 - val_accuracy: 0.8095
# Epoch 22/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.2289 - accuracy: 0.9239 - val_loss: 0.5422 - val_accuracy: 0.8528
# Epoch 23/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.1988 - accuracy: 0.9362 - val_loss: 0.5551 - val_accuracy: 0.8497
# Epoch 24/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.1841 - accuracy: 0.9397 - val_loss: 0.5869 - val_accuracy: 0.8392
# Epoch 25/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.1761 - accuracy: 0.9412 - val_loss: 0.6522 - val_accuracy: 0.8452
# Epoch 26/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.1526 - accuracy: 0.9513 - val_loss: 0.6379 - val_accuracy: 0.8376
# Epoch 27/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.1396 - accuracy: 0.9538 - val_loss: 0.6389 - val_accuracy: 0.8449
# Epoch 28/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.1323 - accuracy: 0.9572 - val_loss: 0.6876 - val_accuracy: 0.8392
# Epoch 29/35
# 9823/9823 [==============================] - 46s 5ms/sample - loss: 0.1636 - accuracy: 0.9515 - val_loss: 0.5741 - val_accuracy: 0.8357
# Epoch 30/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.1077 - accuracy: 0.9655 - val_loss: 0.7049 - val_accuracy: 0.8399
# Epoch 31/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.1061 - accuracy: 0.9686 - val_loss: 0.6971 - val_accuracy: 0.8414
# Epoch 32/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.0994 - accuracy: 0.9710 - val_loss: 0.9388 - val_accuracy: 0.8297
# Epoch 33/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.0916 - accuracy: 0.9734 - val_loss: 0.9118 - val_accuracy: 0.8442
# Epoch 34/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.0964 - accuracy: 0.9700 - val_loss: 0.8702 - val_accuracy: 0.8402
# Epoch 35/35
# 9823/9823 [==============================] - 45s 5ms/sample - loss: 0.0861 - accuracy: 0.9733 - val_loss: 0.7817 - val_accuracy: 0.8440

# %%
plot.plot(trained.history['accuracy'])
plot.plot(trained.history['val_accuracy'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

plot.plot(trained.history['loss'])
plot.plot(trained.history['val_loss'])
plot.title('Model loss')
plot.ylabel('Loss')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %%
test_images,test_labels = get_images('../input/intel-image-classification/seg_test/seg_test/')
test_images = np.array(test_images)
test_labels = np.array(test_labels)
model.evaluate(test_images,test_labels, verbose=1)
# Out:
# 3000/3000 [==============================] - 4s 1ms/sample - loss: 0.8308 - accuracy: 0.8413
# [0.8307614385684331, 0.8413333]

# %%
pred_images,no_labels = get_images('../input/intel-image-classification/seg_pred/')
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# (7301, 150, 150, 3)

# %%
fig = plot.figure(figsize=(30, 30))
outer = gridspec.GridSpec(5, 5, wspace=0.2, hspace=0.2)

for i in range(25):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,subplot_spec=outer[i], wspace=0.1, hspace=0.1)
    rnd_number = randint(0,len(pred_images))
    pred_image = np.array([pred_images[rnd_number]])
    pred_class = get_classlabel(model.predict_classes(pred_image)[0])
    pred_prob = model.predict(pred_image).reshape(6)
    for j in range(2):
        if (j%2) == 0:
            ax = plot.Subplot(fig, inner[j])
            ax.imshow(pred_image[0])
            ax.set_title(pred_class)
            ax.set_xticks([])
            ax.set_yticks([])
            fig.add_subplot(ax)
        else:
            ax = plot.Subplot(fig, inner[j])
            ax.bar([0,1,2,3,4,5],pred_prob)
            fig.add_subplot(ax)
